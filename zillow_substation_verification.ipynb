# %% [markdown]
# # Explore whether the Zillow Data has the accurate substation attached
#
# The substation attachment to the Zillow house data was completed before the  start of this project. This repository explores the accuracy of the pre-assingments. The pre-assignments are also in a csv as opposed to in the geo-spatial format. This repository also explores any potential differences between the csv data and the geo-spatial Zillow data.

# %%
# load necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point # to make the lat and long of the zillow data into a gpd object
from shapely.geometry import box  # To create polygon bounding box
import glob
import folium

# %%
# SDGE substation polygons
sdge_substations = gpd.read_file("../../../../capstone/electrigrid/data/utilities/sandiego_grid/substation_sdge.geojson")

# %%
sdge_substations.head()
# Out:
#    OBJECTID            NAME FACILITYID   SUBSTATIONTYPE DISTRICT IMAP_VOLTAGE  \
# 0     24321          CANNON        CAN        138/12 kV       NC         12kV
# 1     24322  BOULEVARD EAST        BUE  138/69/12.47 kV       EA         12kV
# 2     24323         GRANITE         GR         69/12 kV       EA         12kV
# 3     24324         KYOCERA         KA         69/12 kV       BC         12kV
# 4     24325            PALA         PA         69/12 kV       NE         12kV
#
#    IMAP_LOAD_PROFILE  EXIST_GEN  QUE_GEN  TOT_GEN  PROJ_LOAD  PENETRATION  \
# 0  (576 Data Points)      44.73     3.79    48.53      47.12         37.0
# 1  (576 Data Points)       3.70     7.30    11.01       4.48         12.0
# 2  (576 Data Points)      57.38     1.52    58.90      93.14         47.0
# 3  (576 Data Points)        NaN     0.00      NaN        NaN         30.0
# 4  (576 Data Points)      22.68     1.34    24.02      15.91         75.0
#
#                                             geometry
# 0  POLYGON ((-117.35695 33.16298, -117.35695 33.1...
# 1  POLYGON ((-116.39242 32.65018, -116.39242 32.6...
# 2  POLYGON ((-116.87850 32.76981, -116.87856 32.7...
# 3  POLYGON ((-117.14036 32.81960, -117.14036 32.8...
# 4  POLYGON ((-117.19347 33.37029, -117.19347 33.3...

# %%
# rename the substation name for consistency with other dfs
# sdge_substations = sdge_substations.rename(columns={'NAME' : 'Sub'},
#                                            inplace = True)

# %%
# read in the zillow geo data 
zillowmap = gpd.read_file("../../../../capstone/electrigrid/data/buildings/final_zillow.gpkg")

# %%
zillowmap.head()
# Out:
#     type    year  room  heat  cool   own   unit     value sqft_type    sqft  \
# 0  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 1  Multi  2003.0   1.0  None  None  None  224.0  240117.0    living   936.0
# 2  Multi  2003.0   1.0  None  None     I  224.0  261770.0    living   997.0
# 3  Multi  2003.0   1.0  None  None  None  224.0  223337.0    living  1002.0
# 4  Multi  2003.0   1.0  None  None  None  224.0  241347.0    living  1003.0
#
#    ID        GEOID p_ID     area   code                        geometry
# 0   3  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 1   4  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 2   5  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 3   6  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 4   7  06001403302  468  PGE/SCE  RR106  POINT (564449.237 4183218.817)

# %% [markdown]
# We don't need all of the zillow points for this analysis. Let's clip the zillow points with the substation polygons. First we have to make sure that they are in the same CRS.

# %%
# view the CRS of the sdge substations
print(sdge_substations.crs)

# change the crs of the zillowmap
sd_zillow = zillowmap.to_crs('EPSG:4326')
# Out:
# EPSG:4326

# %%
# clip the zillow with the sdge substations
sd_zillow = gpd.clip(sd_zillow, sdge_substations)

# %% [markdown]
# The p_ID is the substation ID. Let's join this with the data frame that has the ID and the substation name so that we have both and can easily identify whether the substation assignment matches when we map it with the San Diego substation polygons.

# %%
# read in zillow csv
substation_id = pd.read_csv("../../../../capstone/electrigrid/data/buildings/zillow_cats_ica_joined.csv")

substation_id.head()
# Out:
#    bus_i     kV          Type            Sub   p_ID     area         GEOID  \
# 0    1.0  115.0  'Substation'         jenney  h1334   Others  6.001427e+09
# 1    2.0   66.0  'Substation'            NaN    NaN      NaN           NaN
# 2    3.0   66.0  'Substation'            NaN    NaN      NaN           NaN
# 3    4.0  230.0  'Substation'  castro valley    167  PGE/SCE  6.001431e+09
# 4    5.0  115.0  'Substation'         jarvis     67  PGE/SCE  6.001440e+09
#
#        ID           X          Y
# 0  1746.0 -122.242977  37.772369
# 1     NaN         NaN        NaN
# 2     NaN         NaN        NaN
# 3   153.0 -122.061266  37.691784
# 4    65.0 -122.017544  37.595334

# %% [markdown]
# For now we just need the substation name and the substation ID.

# %%
# select only the necessary columns
substation_id = substation_id[['Sub', 'p_ID']]

# %% [markdown]
# Now that we have a clean ID and substation data frame we can use it to verify that the substation IDs were accurately assigned.

# %%
zillow_subid = pd.merge(sd_zillow, 
                        substation_id,
                        how = 'left', 
                        on = 'p_ID')

# %%
zillow_subid.head()
# Out:
#     type    year  room  heat  cool   own   unit     value sqft_type    sqft  \
# 0  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 1  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 2  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 3  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 4  Multi  2003.0   1.0  None  None  None  224.0  240117.0    living   936.0
#
#    ID        GEOID p_ID     area   code                     geometry  \
# 0   3  06001403302  468  PGE/SCE  RR106  POINT (-122.26800 37.79429)
# 1   3  06001403302  468  PGE/SCE  RR106  POINT (-122.26800 37.79429)
# 2   3  06001403302  468  PGE/SCE  RR106  POINT (-122.26800 37.79429)
# 3   3  06001403302  468  PGE/SCE  RR106  POINT (-122.26800 37.79429)
# 4   4  06001403302  468  PGE/SCE  RR106  POINT (-122.26800 37.79429)
#
#          Sub
# 0  oakland c
# 1  oakland c
# 2  oakland c
# 3  oakland c
# 4  oakland c

# %%
# initial plot of san diego zillow points from the geopackage
# fig, ax = plt.subplots()

# sdge_substations.plot(ax=ax,
#                       column = 'NAME')

# zillow_subid.plot(ax = ax, 
#                   column = 'Sub')

# ax.set_title('San Diego Substation Polygons')
# ax.axis('off')

# plt.show()

# %% [markdown]
# The map above takes too long to run.(It didnt run in 40 minutes). Let's sample some points to get a better look at the data.

# %%
# how big is the dataset 
zillow_subid.shape
# Out:
# (2767760, 17)

# %% [markdown]
# There are 2,767,760 rows! This is too many. Let's take a sample to view the results.

# %%
subset_subid = zillow_subid.sample_points(2000)
# Out:
# /Users/sofiarodas/.conda/envs/electrigrid-env/lib/python3.11/site-packages/pandas/core/series.py:4943: UserWarning: Sampling is not supported for Point geometry type.
#   ).apply()

# %%
subset_subid.head()
# Out:
# 0    MULTIPOINT EMPTY
# 1    MULTIPOINT EMPTY
# 2    MULTIPOINT EMPTY
# 3    MULTIPOINT EMPTY
# 4    MULTIPOINT EMPTY
# Name: sampled_points, dtype: geometry

# %%
# initial plot of san diego zillow points from the geopackage
fig, ax = plt.subplots()

sdge_substations.plot(ax=ax,
                      column = 'NAME')

subset_subid.plot(ax = ax, 
                  column = 'Sub')

ax.set_title('San Diego Substation Polygons')
ax.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 7
#       2 fig, ax = plt.subplots()
#       4 sdge_substations.plot(ax=ax,
#       5                       column = 'NAME')
# ----> 7 subset_subid.plot(ax = ax,
#       8                   column = 'Sub')
#      10 ax.set_title('San Diego Substation Polygons')
#      11 ax.axis('off')
#
# File ~/.conda/envs/electrigrid-env/lib/python3.11/site-packages/geopandas/geoseries.py:876, in GeoSeries.plot(self, *args, **kwargs)
#     874 @doc(plot_series)
#     875 def plot(self, *args, **kwargs):
# --> 876     return plot_series(self, *args, **kwargs)
#
# File ~/.conda/envs/electrigrid-env/lib/python3.11/site-packages/geopandas/plotting.py:403, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     401     bounds = s.total_bounds
#     402     y_coord = np.mean([bounds[1], bounds[3]])
# --> 403     ax.set_aspect(1 / np.cos(y_coord * np.pi / 180))
#     404     # formula ported from R package sp
#     405     # https://github.com/edzer/sp/blob/master/R/mapasp.R
#     406 else:
#     407     ax.set_aspect("equal")
#
# File ~/.conda/envs/electrigrid-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:1669, in _AxesBase.set_aspect(self, aspect, adjustable, anchor, share)
#    1667     aspect = float(aspect)  # raise ValueError if necessary
#    1668     if aspect <= 0 or not np.isfinite(aspect):
# -> 1669         raise ValueError("aspect must be finite and positive ")
#    1671 if share:
#    1672     axes = {sibling for name in self._axis_names
#    1673             for sibling in self._shared_axes[name].get_siblings(self)}
#
# ValueError: aspect must be finite and positive
